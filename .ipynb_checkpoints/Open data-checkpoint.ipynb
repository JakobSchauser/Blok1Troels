# %%
import uproot
import pandas as pd
import numpy as np

path = "CernData/mc15_13TeV.361203.Pythia8_A2_MSTW2008LO_ND_minbias.30062015_v0_per_0.root"

# %%
dat_amount = 1e4

file = uproot.open(path)
tree = file['tree']
df = tree.pandas.df("v0_rxy v0_chi2 cosTheta v0_ks_mass v0_rxyErr pT ntrk_pv0 a0 calpha a0xy pv0_y trueKs".split(" "), entrystop = dat_amount)
df_all = tree.pandas.df(entrystop = dat_amount)

# %%
df
# Out:
#           v0_rxy   v0_chi2  cosTheta  v0_ks_mass  v0_rxyErr          pT  \
# entry
# 0      22.167784  2.382054  0.999984  494.268921   0.123808  201.337692
# 1      47.610825  3.497677  0.998978  397.069916   0.151519  102.981972
# 2       0.817319  0.498025 -0.976455  501.326752   0.357613  206.017105
# 3       8.774105  0.005986  0.981570  489.352905   1.579550  184.768997
# 4       6.396118  0.059769 -0.814891  476.383453   1.854471  145.254715
# ...          ...       ...       ...         ...        ...         ...
# 9995    1.066108  4.129388  0.139133  433.090363   0.679598  160.954178
# 9996    0.885159  4.982543 -0.657633  802.322266   2.125089  198.209412
# 9997    0.415248  3.601418  0.926554  805.138794   0.453003  142.447861
# 9998    3.107275  2.198490  0.994760  625.639282   1.976296  275.929565
# 9999    0.776125  1.222184  0.366400  714.178467   0.272635  146.462112
#
#        ntrk_pv0        a0    calpha      a0xy     pv0_y  trueKs
# entry
# 0            62  0.133528  0.903624  0.060672  0.004393       1
# 1            62  2.288277  0.974039  0.757474  0.004393       0
# 2            10  0.450838  0.744703  0.352496 -0.035856       0
# 3            26  5.507392  0.943936  4.042985  0.036038       0
# 4            26  5.185442  0.717841  4.279605  0.036038       0
# ...         ...       ...       ...       ...       ...     ...
# 9995         17  1.170111 -0.463433  1.120360  0.034121       0
# 9996         17  1.007288  0.384388  0.135382  0.034121       0
# 9997         17  0.224206  0.503464  0.124195  0.034121       0
# 9998         17  2.028279  0.956594  1.823122  0.034121       0
# 9999         17  0.700262  0.437966  0.666694  0.034121       0
#
# [10000 rows x 12 columns]
