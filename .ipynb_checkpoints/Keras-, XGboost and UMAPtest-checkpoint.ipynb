# %% [markdown]
# - beskrivelse af detector
#     - pixel vs. tct
#         - cut ved min. 4 hits i alt eller sig at vi er ligeglade
# - foton, k_short and lambda description
#     - henfaldstid, ladning osv.
# - bump i detecter ved fotons reaktion brug google-figur
# - lav simpel reweight. test imod en gbreweight
#     - reweight enkelte variable
# - skrive om, at vi primært udvikler metoder, ikke prøver at få svar
# - kun 5 frihedsgrader pga. helix-fit. Vi har x,y,px,py,pz hvor z er fitttet
# - skriv om koordinatsystem.
# - skriv om udvælgelsen af data fra CERNs side

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d 
import scipy
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import sklearn, xgboost, uproot
from scipy import stats
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_curve,roc_auc_score
from sklearn.ensemble import AdaBoostClassifier
# from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import JFuncs
import umap
import dill
from numpy import logical_and as npand
import shap
import warnings
import JohannFunctions as nnfuncs
import hep_ml
from hep_ml.uboost import uBoostClassifier
import importlib
from scipy.integrate import solve_ivp
from numpy.linalg import norm
importlib.reload(nnfuncs)
warnings.filterwarnings('ignore')
# sns.set()
sns.reset_orig()
# %matplotlib inline


def hist(dat,bins=100,ax = None,label="data"):
    if(ax==None):
        fig,ax = plt.subplots(figsize=(10,5))
    ax.hist(dat,bins,histtype="step",label=label)
def hists(dats,bins=100,label="data"):
    plt.figure(figsize=(10,5))
    for d in dats:
        plt.hist(d,bins,histtype="step",label=label)
    
def tf(d):
    return d[dat["trueKs"].astype(bool)],d[~dat["trueKs"].astype(bool)]

    

def preprocess(l):
    return (l-np.mean(l))/np.std(l)
shapval = "cosTheta v0_ks_mass pT v0_rxyErr v0_rxy v0_chi2 ntrk_pv0 eventCounter a0 a0xy pv0_y calpha v0_ks_massErr epsilon1 epsilon2 v0_ptErr v0_p v0_pz1 v0_phi2 v0_y".split(" ")
mass_uncorrelated = ["v0_chi2","v0_px1","v0_phi1","v0_py1","v0_py","v0_py2","v0_phi2","v0_px2","v0_px"]

def logit(x):
    return np.log(x/(1-x))

# %%
bigDat = True

if bigDat:
    path = "CernData/mc15_13TeV.361203.Pythia8_A2_MSTW2008LO_ND_minbias.30062015_v0_per_0.root"
    dat_amount = 2*1e6

    file = uproot.open(path)
    tree = file['tree']
    dat = tree.pandas.df(shapval+["trueKs"], entrystop=dat_amount)
    df_all = tree.pandas.df(entrystop = dat_amount)
    moredat = tree.pandas.df(shapval+["trueKs"], entrystop=2*dat_amount)
    moredat = moredat[int(dat_amount):]
else:
    path = "dataframe_v0_mc.dat"
    dat = pd.read_pickle(path)


# print([head for head in dat])

# %%
if True:
    path = "CernData/data15_13TeV.00267358.physics_MinBias.30062015_v0_per_0.root"
    dat_amount = 1e8

    file = uproot.open(path)
    tree = file['tree']
    truedat = tree.pandas.df(shapval, entrystop=dat_amount)

    truedat_all = tree.pandas.df(entrystop=dat_amount)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-129-51fc9f8bb2b3> in <module>
#       7     truedat = tree.pandas.df(shapval, entrystop=dat_amount)
#       8
# ----> 9     truedat_all = tree.pandas.df(entrystop=dat_amount)
#
# ~\Anaconda3\lib\site-packages\uproot\_connect\_pandas.py in df(self, branches, namedecode, entrystart, entrystop, flatten, flatname, awkwardlib, cache, basketcache, keycache, executor, blocking)
#      30     def df(self, branches=None, namedecode="utf-8", entrystart=None, entrystop=None, flatten=True, flatname=None, awkwardlib=None, cache=None, basketcache=None, keycache=None, executor=None, blocking=True):
#      31         import pandas
# ...

# %% [markdown]
# # Simple fit

# %%
sns.set()
off = 0
bg = lambda x,a,b,c,d: np.polynomial.polynomial.polyval(x,[a,b,c,d])
def doublegauss(x,mu,sigma1,sigma2,N,f):
    return N*(stats.norm.pdf(x,mu,sigma1)*f + stats.norm.pdf(x,mu,sigma2)*(1-f))

def sg(x,mu,sigma,s):
    return s*stats.norm.pdf(x,mu,sigma)+off
fig, axs = plt.subplots(2,2,figsize=(12,7),sharex=False)

def ff(x,mu,sigma1,sigma2,s,a,b,c,d,N,f):
    return bg(x,a,b,c,d) + doublegauss(x,mu,sigma1,sigma2,N,f)
axs = axs.flatten()

full = lambda x,a,b,c,d,mu,sigma1,sigma2,s,f: doublegauss(x,mu,sigma1,sigma2,s,f)+np.polynomial.polynomial.polyval(x,[a,b,c,d])

#MC

amount = int(2*6*1e6)
d = dat[:amount]
rng = np.logical_and(d['v0_ks_mass']>400,d['v0_ks_mass']<600)
y,x = np.histogram(d[rng]['v0_ks_mass'],200) 
x = np.array([0.5*(x[i]+x[i+1]) for i in range(len(x)-1)])

lt = np.logical_or(x<466,x>525)
yerrs = np.sqrt(y)
mibg,ax = JFuncs.chi2fit(x[lt],y[lt],yerrs[lt],bg,{"a":-1,"b":1,"c":1,"d":350},draw=False,label="MC",text=(0.2,0.05))
y -= bg(x,*mibg.args).astype(int)

guess = scipy.optimize.curve_fit(sg, x, y, p0 = [497, 4, 500])[0]
mu, sigma, s = guess
mi,ax = JFuncs.chi2fit(x,y,yerrs,doublegauss,{"mu":mu,"sigma1":sigma,"sigma2":2*sigma,"N":s,"f":0.1},draw=False,label="MC",text=(0.1,0.3))
# mi,ax = JFuncs.chi2fit(x,y,yerrs,sg,{"mu":mu,"sigma":sigma,"s":N},ax=axs[1],draw=True,label="MC",)

y += bg(x,*mibg.args).astype(int)


axs[0].errorbar(x,y,yerr=yerrs,fmt = 'k.',capsize = 2,label = "MC")
xx = np.linspace(min(x),max(x),100)
axs[0].plot(xx,doublegauss(xx,*mi.args)+bg(xx,*mibg.args),ls='--',c='r',label = "Peak")
axs[0].plot(xx,bg(xx,*mibg.args),ls='--',c='c',label = "Background")

axs[0].fill_between(xx,np.zeros(len(xx)),bg(xx,*mibg.args),color='c',alpha = 0.5)
axs[0].fill_between(xx,bg(xx,*mibg.args),doublegauss(xx,*mi.args)+bg(xx,*mibg.args),color='r',alpha = 0.5)

p = stats.chi2.sf(mi.fval,len(y)-9)
dstr = "$\mu$ = {:.1f}$\pm${:.1}\n$\sigma_1$ = {:.3}$\pm${:.1}\n$\sigma_2$ = {:.3}$\pm${:.1}\n f = {:.3}$\pm${:.2}\n p-val = {:.3}".format(mi.args[0],mi.errors[0],mi.args[1],mi.errors[1],mi.args[2],mi.errors[2],mi.args[4],mi.errors[4],p)
axs[0].text(0.1,0.6,dstr,transform=axs[0].transAxes)
axs[0].legend()

#data
d = truedat[:amount]
rng = np.logical_and(d['v0_ks_mass']>400,d['v0_ks_mass']<600)
y,x = np.histogram(d[rng]['v0_ks_mass'],200) 
x = np.array([0.5*(x[i]+x[i+1]) for i in range(len(x)-1)])

lt = np.logical_or(x<475,x>525)
yerrs = np.sqrt(y)
mibg,ax = JFuncs.chi2fit(x[lt],y[lt],yerrs[lt],bg,{"a":-1,"b":1,"c":1,"d":350},draw=False,label="Data",text=(0.1,0.05))
y -= bg(x,*mibg.args).astype(int)

guess = scipy.optimize.curve_fit(sg, x, y, p0 = [497, 4, 500])[0]
mu, sigma, s = guess
mi,ax = JFuncs.chi2fit(x,y,yerrs,doublegauss,{"mu":mu,"sigma1":sigma,"sigma2":2*sigma,"N":s,"f":0.1},draw=False,label="Data",text=(0.1,0.3))

y += bg(x,*mibg.args).astype(int)

axs[1].errorbar(x,y,yerr=yerrs,fmt = 'k.',capsize = 2,label = "Data")
xx = np.linspace(min(x),max(x),100)
axs[1].plot(xx,doublegauss(xx,*mi.args)+bg(xx,*mibg.args),ls='--',c='r',label = "Peak")
axs[1].plot(xx,bg(xx,*mibg.args),ls='--',c='c',label = "Background")

axs[1].fill_between(xx,np.zeros(len(xx)),bg(xx,*mibg.args),color='c',alpha = 0.5)
axs[1].fill_between(xx,bg(xx,*mibg.args),doublegauss(xx,*mi.args)+bg(xx,*mibg.args),color='r',alpha = 0.5)
p = stats.chi2.sf(mi.fval,len(y)-9)

dstr = "$\mu$ = {:.1f}$\pm${:.1}\n$\sigma_1$ = {:.3}$\pm${:.2}\n$\sigma_2$ = {:.3}$\pm${:.1}\n f = {:.3}$\pm${:.1}\n p-val = {:.3}".format(mi.args[0],mi.errors[0],mi.args[1],mi.errors[1],mi.args[2],mi.errors[2],mi.args[4],mi.errors[4],p)
axs[1].text(0.1,0.1,dstr,transform=axs[1].transAxes)
axs[1].legend()

print(stats.chi2.sf(mi.fval,len(y)-9))




#mean 1116 std hhv 4 og 8
amount *= 30
d = df_all[:amount]
rng = np.logical_and(d['v0_lb_mass']>1000,d['v0_lb_mass']<1150)
y,x = np.histogram(d[rng]['v0_lb_mass'],200) 
x = np.array([0.5*(x[i]+x[i+1]) for i in range(len(x)-1)])
yerrs = np.sqrt(y)

lt = np.logical_or(x<1110,x>1125)
yerrs = np.sqrt(y)
mibg,ax = JFuncs.chi2fit(x[lt],y[lt],yerrs[lt],bg,{"a":-1,"b":1,"c":1,"d":350},draw=False,label="Data",text=(0.1,0.05))
y -= bg(x,*mibg.args).astype(int)

guess = scipy.optimize.curve_fit(sg, x, y, p0 = [1116, 4, 500])[0]
mu, sigma, s = guess
mi,ax = JFuncs.chi2fit(x,y,yerrs,doublegauss,{"mu":mu,"sigma1":sigma,"sigma2":2*sigma,"N":s,"f":0.1},draw=False,label="Data",text=(0.1,0.3))

y += bg(x,*mibg.args).astype(int)

axs[2].errorbar(x,y,yerr=yerrs,fmt = 'k.',capsize = 2,label = "MC")
xx = np.linspace(min(x),max(x),100)
axs[2].plot(xx,doublegauss(xx,*mi.args)+bg(xx,*mibg.args),ls='--',c='r',label = "Peak")
axs[2].plot(xx,bg(xx,*mibg.args),ls='--',c='c',label = "Background")

axs[2].fill_between(xx,np.zeros(len(xx)),bg(xx,*mibg.args),color='c',alpha = 0.5)
axs[2].fill_between(xx,bg(xx,*mibg.args),doublegauss(xx,*mi.args)+bg(xx,*mibg.args),color='r',alpha = 0.5)
p = stats.chi2.sf(mi.fval,len(y)-9)

dstr = "$\mu$ = {:.1f}$\pm${:.1}\n$\sigma_1$ = {:.3}$\pm${:.2}\n$\sigma_2$ = {:.3}$\pm${:.1}\n f = {:.3}$\pm${:.2}\n p-val = {:.3}".format(mi.args[0],mi.errors[0],mi.args[1],mi.errors[1],mi.args[2],mi.errors[2],mi.args[4],mi.errors[4],p)
axs[2].text(0.65,0.1,dstr,transform=axs[2].transAxes)
axs[2].legend()

print(stats.chi2.sf(mi.fval,len(y)-9))


bg = lambda x,a,b: np.polynomial.polynomial.polyval(x,[a,b])


d = truedat_all[:amount]
rng = np.logical_and(d['v0_lb_mass']>1102,d['v0_lb_mass']<1130)
y,x = np.histogram(d[rng]['v0_lb_mass'],200) 
x = np.array([0.5*(x[i]+x[i+1]) for i in range(len(x)-1)])
yerrs = np.sqrt(y)

lt = np.logical_or(x<1110,x>1120)
yerrs = np.sqrt(y)
mibg,ax = JFuncs.chi2fit(x[lt],y[lt],yerrs[lt],bg,{"a":-1,"b":2000},draw=False,label="Data",text=(0.1,0.05))
y -= bg(x,*mibg.args).astype(int)

guess = scipy.optimize.curve_fit(sg, x, y, p0 = [1116, 4, 500])[0]
mu, sigma, s = guess
mi,ax = JFuncs.chi2fit(x,y,yerrs,doublegauss,{"mu":mu,"sigma1":sigma,"sigma2":2*sigma,"N":s,"f":0.1},draw=False,label="Data",text=(0.1,0.3))

y += bg(x,*mibg.args).astype(int)

axs[3].errorbar(x,y,yerr=yerrs,fmt = 'k.',capsize = 2,label = "Data")
xx = np.linspace(min(x),max(x),100)
axs[3].plot(xx,doublegauss(xx,*mi.args)+bg(xx,*mibg.args),ls='--',c='r',label = "Peak")
axs[3].plot(xx,bg(xx,*mibg.args),ls='--',c='c',label = "Background")

axs[3].fill_between(xx,np.zeros(len(xx)),bg(xx,*mibg.args),color='c',alpha = 0.5)
axs[3].fill_between(xx,bg(xx,*mibg.args),doublegauss(xx,*mi.args)+bg(xx,*mibg.args),color='r',alpha = 0.5)
p = stats.chi2.sf(mi.fval,len(y)-9)

dstr = "$\mu$ = {:.1f}$\pm${:.1}\n$\sigma_1$ = {:.3}$\pm${:.1}\n$\sigma_2$ = {:.3}$\pm${:.2}\n f = {:.3}$\pm${:.1}\n p-val = {:.3}".format(mi.args[0],mi.errors[0],mi.args[1],mi.errors[1],mi.args[2],mi.errors[2],mi.args[4],mi.errors[4],p)
axs[3].text(0.65,0.1,dstr,transform=axs[3].transAxes)
axs[3].legend(shadow=True)

print(stats.chi2.sf(mi.fval,len(y)-9))
print(mi.fval)

axs[0].set_title("K-short fit on MC",fontsize=14)
axs[1].set_title("K-short fit on data",fontsize=14)
axs[2].set_title("Lambda fit on MC",fontsize=14)
axs[3].set_title("Lambda fit on data",fontsize=14)


# mi,ax = JFuncs.chi2fit(x,y,yerrs,sg,{"mu":mu,"sigma":sigma,"s":N},ax=axs[1],draw=True,label="MC",)
fig.tight_layout()
plt.show()
sns.reset_orig()
# Out:
# 0.4365291869436258
# 5.144327718733107e-06
# 0.006427657058974464
# 243.0669975536204

# %%
bg = lambda x,a,b,c,d: np.polynomial.polynomial.polyval(x,[a,b,c,d])
def doublegauss(x,mu,sigma1,sigma2,N,f):
    return N*(stats.norm.pdf(x,mu,sigma1)*f + stats.norm.pdf(x,mu,sigma2)*(1-f))


def full_fit(x,mu,sigma1,sigma2,N,f,a,b,c,d)
    return bg(x,a,b,c,d) + doublegauss(x,mu,sigma1,sigma2,N,f)

d = truedat[:amount]
rng = np.logical_and(d['v0_ks_mass']>400,d['v0_ks_mass']<600)
y,x = np.histogram(d[rng]['v0_ks_mass'],200) 
x = x[:-1]

lt = np.logical_or(x<475,x>525)


#cut out peak




mi,ax = JFuncs.chi2fit(x,y,yerrs,bg,{"mu":mu,"sigma1":sigma,"sigma2":2*sigma,"N":s,"f":0.1},draw=False,label="Data",text=(0.1,0.3))

# %%
plt.plot(y-doublegauss(x,*mi.args)-bg(x,*mibg.args),'.')

# %%
print((497.680-497.611)/np.sqrt(0.324**2+0.013**2))
print((1116.22-1115.683)/np.sqrt(0.292**2+0.006**2))
# Out:
# 0.21279174600361572
# 1.8386529806134821

# %%
y,x = np.histogram(df_all['v0_lb_mass'],2000) 
x = x[:-1]
yerrs = np.sqrt(y)
plt.errorbar(x,y,yerr=yerrs,fmt = 'k.',capsize = 2,label = "Data")
plt.xlim(1000,1200)
# Out:
# (1000.0, 1200.0)

# %% [markdown]
# # not so simple everything else

# %%
pva0 = "v0_ks_mass cosTheta v0_rxy v0_ks_massErr trueKs".split(" ")

pg = sns.pairplot(preprocess(dat[pva0][:10000]),hue="trueKs",diag_kind="kde",plot_kws=dict(marker=".", size=4),palette=sns.color_palette("deep"))

pg._legend.remove()
plt.tight_layout()

# %%
rxy_low_min, rxy_high_min, chi2_high_min, cos_Theta_low_min, mass_low_min, mass_high_min = -60.818,114.783,3.782,0.9976,450,550
#tak nn
def cutter(df):
    label = np.ones(len(df))
    label[np.logical_or(df['v0_rxy'] < rxy_low_min, df['v0_rxy'] > rxy_high_min)] = 0
    print(1,sum(label))
    label[df['v0_chi2'] > chi2_high_min] = 0
    print(2,sum(label))
    
    label[df['cosTheta'] < cos_Theta_low_min] = 0
    print(3,sum(label))
    
    label[np.logical_or(df['v0_ks_mass'] < mass_low_min, df['v0_ks_mass'] > mass_high_min)] = 0
    print(4,sum(label))
    
    return label



ps = "v0_rxy v0_chi2 cosTheta v0_ks_mass".split(" ")

amount = int(1e5)

td = (truedat[ps])[:amount]

td_test = (truedat[ps])[amount:int(amount*2)]

target = cutter(td).astype(bool)#pd.Series(cutter(td), dtype = bool)

test_target = cutter(td_test).astype(bool)#pd.Series(cutter(td_test), dtype = bool)

td,td_test = preprocess(td),preprocess(td_test)
# dn = preprocess(dat[gg]).dropna()[:amount]




# target = dat["trueKs"][:amount]

# sns.pairplot(preprocess(dat[shap[:7]+["trueKs"]]), hue='trueKs')#,palette='Pastel1')
# plt.plot()
reducer = umap.UMAP(n_neighbors=20)

print("Made UMAP")

mapper = reducer.fit(td)

print("Fittet UMAP")

tembedding = mapper.transform(td_test)


print("Transformed UMAP")

# print(embedding.shape)


plt.figure(figsize=(14,14))
plt.scatter(
    tembedding[:, 0],
    tembedding[:, 1],
    c=[sns.color_palette()[x] for x in test_target],
    cmap='Spectral',
#     marker = '*',
#     s=5,
    alpha=1,
    label="irl"
    )

# plt.scatter(
#     tembedding[:, 0],
#     tembedding[:, 1],
# #     c=[sns.color_palette()[x] for x in target],
#     c='red',
#     s=0.1,
#     label="irl"
#     )



# Ks = mapper.transform(preprocess(dat[dat["trueKs"].astype(bool)][gg]).dropna())
# plt.scatter(
#     Ks[:, 0],
#     Ks[:, 1],
#     c="red",
#     marker = '*',
#     s=0.1
#     )


plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the Shap-value-chosen dataset', fontsize=24)
plt.legend()
plt.show()
print("Plottet UMAP")
# Out:
# 1 81821.0
# 2 46744.0
# 3 3928.0
# 4 2089.0
# 1 83927.0
# 2 48865.0
# 3 5473.0
# 4 3079.0
# Made UMAP
# Fittet UMAP
# Transformed UMAP
# C:\Users\jakob\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
# Plottet UMAP

# %%
params = "cosTheta pT v0_rxyErr v0_rxy v0_chi2 ntrk_pv0 a0 a0xy pv0_y calpha v0_ks_massErr epsilon1 epsilon2 v0_ptErr v0_p v0_pz1 v0_phi2 v0_y".split(" ")


s = int(4*1e4)
d = preprocess(dat[:s][params])
td = preprocess(truedat[:s][params])

target = dat[:s]["trueKs"]

reducer = umap.UMAP(n_components=2,n_neighbors=20,transform_seed=420)


allesammen = pd.concat([d,td])

print("Made UMAP")



te = reducer.fit(d,target)
print("Fittet UMAP")


# print(embedding.shape)
# Out:
# Made UMAP
# Fittet UMAP

# %%
dd = preprocess(dat[s:2*s][params])

# cs = dat[s:2*s]["trueKs"]



plt.figure(figsize=(12,10))

# t = te.transform(dd)
# cs = dat[s:2*s]["trueKs"]
# plt.scatter(
#     t[:, 0],
#     t[:, 1],
#     alpha=0.8,
#     cmap='viridis',
#     c=cs,
#     label="MC",
#     s=0.8,
#     marker="o"

#     )


ddd = preprocess(dat[s:s*2][params])
t = te.transform(ddd)
# t = te.transform(td)

# y_pred = model.predict_proba(td[ps])
# cs = y_pred[:,0]<0.4
cs = dat[s:s*2]["trueKs"]
plt.scatter(
    t[:, 0],
    t[:, 1],
    cmap='Accent',
    alpha=1,
    c=cs,
    label="MC",
    s=1,

    )
# plt.colorbar()
plt.legend()
plt.show()

# %%
hist(truedat[:s][t[:, 0]>5]["v0_ks_mass"],100)

# %% [markdown]
# # UBoost testing with Jones

# %%
params = "cosTheta pT v0_rxyErr v0_rxy v0_chi2 ntrk_pv0 a0 a0xy pv0_y calpha v0_ks_massErr epsilon1 epsilon2 v0_ptErr v0_p v0_pz1 v0_phi2 v0_y".split(" ")


s = int(4*1e4)
d = preprocess(dat[:s][params])
t1 = dat[:s]["trueKs"]



reducer = umap.UMAP(n_components=len(params)-1,n_neighbors=20,transform_seed=420)



print("Made UMAP")



te = reducer.fit(d,t1)
print("Fittet UMAP")


# print(embedding.shape)
# Out:
# Made UMAP
# Fittet UMAP

# %%
size = len(dat)

dd = preprocess(dat[2*s:size][params])
t2 = dat[2*s:size]["trueKs"]

trans = te.transform(dd)

print("transformed")
umodel = xgboost.XGBClassifier(learning_rate = 0.1,n_estimators = 50)
model  = xgboost.XGBClassifier(learning_rate = 0.1,n_estimators = 50)

umodel.fit(trans, t2,verbose=True,eval_metric ="auc")
print("fittet1")
model.fit(dd, t2,verbose=True,eval_metric ="auc")
print("fittet2")
# Out:
# transformed
# fittet1
# fittet2

# %%
amount = int(1e5)

test_data = moredat[:amount][params]

processed = preprocess(test_data)
transformed = te.transform(processed)

utf = umodel.predict_proba(transformed)
tf = model.predict_proba(processed)



fig, axs = plt.subplots(2,2,figsize=(15,10))

print("uBoost:")
nnfuncs.roc_curve_data(moredat[:amount]["v0_ks_mass"],utf[:,0],ax_roc=axs[0,0],ax_fits=axs[0,1],)
print("Boring Boost:")
nnfuncs.roc_curve_data(moredat[:amount]["v0_ks_mass"],tf[:,0],ax_roc=axs[1,0],ax_fits=axs[1,1])

axs[0,0].set_title("uBoost")
axs[1,0].set_title("Boring Boost")
# Out:
# uBoost:
# Completed fit with Chi2: 132.7, p-val: 0.003 and the total amount of signal 7802 +/- 133, background: 92198
# Completed fit with Chi2: 88.4, p-val: 0.558 and the total amount of signal 966 +/- 77, background: 89034
# Completed fit with Chi2: 89.1, p-val: 0.536 and the total amount of signal 464 +/- 85, background: 79537
# Completed fit with Chi2: 80.0, p-val: 0.787 and the total amount of signal 268 +/- 64, background: 69733
# Completed fit with Chi2: 75.2, p-val: 0.884 and the total amount of signal 199 +/- 125, background: 59801
# Completed fit with Chi2: 74.0, p-val: 0.902 and the total amount of signal 140 +/- 50, background: 49860
# Completed fit with Chi2: 76.7, p-val: 0.858 and the total amount of signal 73 +/- 58, background: 39928
# Completed fit with Chi2: 99.4, p-val: 0.257 and the total amount of signal 89 +/- 31, background: 29911
# Completed fit with Chi2: 94.6, p-val: 0.377 and the total amount of signal 43 +/- 41, background: 19958
# ...

# %%
tfbool = tf[:,0]<0.4

amount = tfbool==t3

plt.hist(dat[s:2*s][tfbool]["v0_ks_mass"],200)
plt.show()

# %%
cosmask = truedat["cosTheta"]>0.997

massk = np.logical_and(truedat["v0_ks_mass"]>400,truedat["v0_ks_mass"]<600)

msk = np.logical_and(cosmask,massk)
t,f = truedat["v0_ks_mass"][msk],truedat["v0_ks_mass"][~msk]


hist(t,200)

y,x = np.histogram(t,200)

bg = lambda x,a,b: x*a+b
func = lambda x,mu,sigma,a,b: stats.norm.pdf(x,mu,sigma)*a+b

fig, ax = plt.subplots(figsize=(13,6))
x = x[:-1]
mi,ax = JFuncs.chi2fit(x,y,np.sqrt(y),bg,{"a":100,"b":80},ax=ax,text=(.1,.4))
plt.show()
fig, ax = plt.subplots(figsize=(13,6))

y = y.astype(float)-bg(x,*mi.args)+500
JFuncs.chi2fit(x,y,np.sqrt(y),func,{"mu":490,"sigma":3,"a":2400,"b":10},ax=ax,text=(.1,.4))
plt.show()

# %% [markdown]
# # trying the imposter-uBoost

# %%
Johanns_decorr = "v0_chi2 v0_px1 v0_phi1 v0_py1 v0_py v0_py2 v0_phi2 v0_px2 v0_px cosTheta a0xy a0 v0_y v0_x v0_rxyErr v0_z pv0_z pv0_y ntrk_pv0 pv0_x".split(" ")

# %%
d = df_all[:int(1e3)]
train_data, train_labels = d[allparams],d["trueKs"]

base_tree = AdaBoostClassifier(n_estimators=50, random_state=0)
clf = uBoostClassifier(uniform_features = ['v0_ks_mass'], uniform_label=0, base_estimator=base_tree,train_features=allparams,random_state=420)
clf.fit(train_data, train_labels)
# Out:
# uBoostClassifier(base_estimator=AdaBoostClassifier(random_state=0),
#                  random_state=420, smoothing=0.5,
#                  train_features=['eventCounter', 'npv', 'ntrk_pv0', 'pv0_x',
#                                  'pv0_y', 'pv0_z', 'a0xy', 'a0', 'a0z',
#                                  'cosTheta', 'v0_chi2', 'v0_x', 'v0_y', 'v0_z',
#                                  'v0_rxy', 'v0_rxyErr', 'v0_px', 'v0_py',
#                                  'v0_pz', 'v0_pt', 'v0_p', 'v0_ptErr',
#                                  'v0_ks_mass', 'v0_la_mass', 'v0_lb_mass',
#                                  'v0_ks_massErr', 'v0_la_massErr',
#                                  'v0_lb_massErr', 'v0_px1', 'v0_py1', ...],
#                  uniform_features=['v0_ks_mass'], uniform_label=0)

# %%
d = df_all[int(1e5):int(1e6)]
train_data, train_labels = d[allparams],d["trueKs"]

xgmodel = AdaBoostClassifier(n_estimators=100, random_state=0)
xgmodel.fit(train_data[Johanns_decorr], train_labels)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
bad = np.append(Johanns_decorr,"v0_ks_mass")
d = df_all[:int(1e4)]
train_data, train_labels = d[bad],d["trueKs"]
test_data = d[int(1e4):2*int(1e4)]
base_tree = AdaBoostClassifier(n_estimators=50, random_state=0)
clf_bad = uBoostClassifier(uniform_features = ['v0_ks_mass'], uniform_label=0, base_estimator=base_tree,train_features=bad,random_state=420)
clf_bad.fit(train_data, train_labels)
# Out:
# uBoostClassifier(base_estimator=AdaBoostClassifier(random_state=0),
#                  random_state=420, smoothing=0.5,
#                  train_features=array(['v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2',
#        'v0_phi2', 'v0_px2', 'v0_px', 'cosTheta', 'a0xy', 'a0', 'v0_y',
#        'v0_x', 'v0_rxyErr', 'v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x',
#        'v0_ks_mass'], dtype='<U10'),
#                  uniform_features=['v0_ks_mass'], uniform_label=0)

# %%
dd = df_all[int(1e4):10*int(1e4)]
test_data,train_labels = dd[allparams],dd["trueKs"]

probau = clf.predict_proba(test_data)
probad = clf_bad.predict_proba(test_data[bad])

proba = xgmodel.predict_proba(test_data[Johanns_decorr])

tfu = probau[:,1]>0.7
tf = proba[:,1]>0.7

# %%
sns.set()
fig, axs = plt.subplots(2,3,figsize=(14,8),sharey = False)
ru = roc_curve(train_labels,probau[:,0])
aucu = roc_auc_score(train_labels,probau[:,0])

axs[0,0].plot(ru[0],ru[1],label = "auc:{:.3}".format(1-aucu))
r = roc_curve(train_labels,proba[:,0])
auc = roc_auc_score(train_labels,proba[:,0])
axs[0,1].plot(r[0],r[1],label = "auc:{:.3}".format(1-auc))

axs[1,0].scatter(test_data["v0_ks_mass"],logit(probau[:,1]),s=0.1)
axs[1,1].scatter(test_data["v0_ks_mass"],proba[:,1],s=0.1)

axs[0,0].set_title("uBoost with (almost) all parameters")
axs[0,1].set_title("adaBoost with non-mass-correlating parameters")
axs[0,2].set_title("uBoost with non-mass-correlating parameters")

axs[1,0].set_ylabel("logit(Predicted probability)")
axs[1,0].set_xlabel("v0_ks_mass")
axs[1,1].set_xlabel("v0_ks_mass")
axs[1,2].set_xlabel("v0_ks_mass")

rbad = roc_curve(train_labels,probad[:,0])
aucbad = roc_auc_score(train_labels,probad[:,0])
axs[0,2].plot(rbad[0],rbad[1],label = "auc:{:.3}".format(1-aucbad))
axs[1,2].scatter(test_data["v0_ks_mass"],logit(probad[:,1]),s=0.1)
fig.tight_layout()
axs[0,0].legend()
axs[0,1].legend()          
axs[0,2].legend()
              
plt.plot()
sns.reset_orig()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,7))
nnfuncs.roc_curve_data(test_data["v0_ks_mass"],y_pred[:,1],ax_roc=axs[0],ax_fits=axs[1])

# %% [markdown]
# # Testing the calculated uncertainty:

# %%
sns.set()

d = truedat
# d = dat
xplot,yplot,eplot = [],[],[]


errs = np.linspace(0,10,30)
mis = []
xs = []
xerss = []
cosmask = d["cosTheta"]>0.997

massk = np.logical_and(d["v0_ks_mass"]>450,d["v0_ks_mass"]<550)

msk = np.logical_and(cosmask,massk)
t,f = d["v0_ks_mass"][msk],d["v0_ks_mass"][~msk]
moredat =  d[msk]
fig, axs = plt.subplots(7,3,figsize=(15,15))
dri = 0
axs=axs.flatten()
for i in range(len(errs)-1):
    rng = np.logical_and(d['v0_ks_massErr']>errs[i],d['v0_ks_massErr']<errs[i+1])
    meanerr = np.mean(d['v0_ks_massErr'][rng])
    l = len(t[rng])
    y,x = np.histogram(t[rng],200)
    fffyyy = y
    if(l>100):
#         print(l)
#         xs.append(errs[i])
        bg = lambda x,a,b: x*a+b
        func = lambda x,mu,sigma,a,b: stats.norm.pdf(x,mu,sigma)*a+b

        x = [(x[i+1]+x[i])/2 for i in range(len(x)-1)]
#         mi,ax = JFuncs.chi2fit(x,y,np.sqrt(y),bg,{"a":10,"b":80},draw=False)
#         y = y.astype(float)-bg(x,*mi.args)
        y -= np.min(y)-10
        if(dri!=16):
            mi, ax = JFuncs.chi2fit(x,y,np.sqrt(y),func,{"mu":494.1,"sigma":errs[i],"a":100,"b":10},ax=axs[dri],draw=True,label="$\sigma$: {:.3}".format(meanerr))
        else:
            mi, ax = JFuncs.chi2fit(x,y,np.sqrt(y),func,{"mu":493.5,"sigma":errs[i],"a":100,"b":10},ax=axs[dri],draw=True,label="$\sigma$: {:.3}".format(meanerr))
        
        if(dri==1 or dri ==14):
            xplot.append(x)
            yplot.append(y)
            eplot.append(meanerr)
        dri+=1
        
        if mi.migrad_ok():
            mis.append(mi)
            xs.append(meanerr)
            xerss.append(np.std(d['v0_ks_massErr'][rng]))
            

vals = [m.values["sigma"] for m in mis]
verrs = [m.errors["sigma"] for m in mis]
fig.tight_layout()
plt.show()
fig,ax = plt.subplots(figsize=(15,5))
mi, ax = JFuncs.chi2fit(xs,vals,verrs,bg,{"a":1,"b":0},draw=True,ax=ax,text=(0.5,0.05))
ax.plot(xs,xs,color="green",alpha=0.7,linestyle='dashed',label="y = x")
plt.title("Measured uncertainty on peak as a function of uncertainty in data",fontsize=14)
# plt.plot(xs,vals,'.')

ax.legend(loc="upper left",shadow=True)
with sns.axes_style("whitegrid"):
    left, bottom, width, height = [.28, 0.6, 0.2, 0.2]
    ax1 = fig.add_axes([left, bottom, width, height])
    JFuncs.chi2fit(xplot[0],yplot[0],np.sqrt(yplot[0]),func,{"mu":494.1,"sigma":eplot[0],"a":100,"b":10},ax=ax1,draw=True,label="$\sigma$: {:.3}".format(eplot[0]))
    ax1.set_xlabel("ks_mass")
    
    left, bottom, width, height = [0.68, .25, 0.2, 0.2]
    ax2 = fig.add_axes([left, bottom, width, height])
    JFuncs.chi2fit(xplot[1],yplot[1],np.sqrt(yplot[1]),func,{"mu":494.1,"sigma":eplot[1],"a":100,"b":10},ax=ax2,draw=True,label="$\sigma$: {:.3}".format(eplot[1]))
    ax2.set_xlabel("ks_mass")
    
ax.indicate_inset([eplot[0]-0.05,eplot[0]+.54,0.1,0.2],ax1)
ax.indicate_inset([eplot[1]-0.05,eplot[1]+1,0.1,0.2],ax2)



ax.set_ylabel("Fitted uncertainty")
ax.set_xlabel("Uncertainty in data")
plt.savefig("fittetuncertaintyflotter.png",dpi=200)
plt.show()

# %%
p1 = "cosTheta pT v0_rxyErr v0_rxy v0_chi2 ntrk_pv0 a0 a0xy pv0_y calpha".split(" ")

p2 = "v0_ks_massErr epsilon1 epsilon2 v0_ptErr v0_p v0_pz1 v0_phi2 v0_y".split(" ")

ps = p1+p2

# ps = Johanns_decorr

models =[]
tsts =[]

X,Y = df_all[ps],df_all[["trueKs"]]

X = preprocess(X)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=420)
eval_s = [(X_train, y_train), (X_test, y_test)]
tsts.append(X_train)
model = xgboost.XGBClassifier(learning_rate = 0.01,n_estimators = 20)
model.fit(X_train, y_train,verbose=True,eval_set=eval_s,early_stopping_rounds=30,eval_metric ="auc")
y_pred = model.predict(X_test)
models.append(model)
predictions = [round(value) for value in y_pred]

accuracy = accuracy_score(y_test, predictions)
results = model.evals_result()

print("Accuracy: {:.3}".format(accuracy * 100.0))
print("AUC: {:.3}".format(np.max(results['validation_0']['auc'])))
# Out:
# [0]	validation_0-auc:0.97758	validation_1-auc:0.977568
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.978087	validation_1-auc:0.978025
# [2]	validation_0-auc:0.978091	validation_1-auc:0.978016
# [3]	validation_0-auc:0.97891	validation_1-auc:0.978795
# [4]	validation_0-auc:0.978935	validation_1-auc:0.978822
# [5]	validation_0-auc:0.982682	validation_1-auc:0.982659
# [6]	validation_0-auc:0.982713	validation_1-auc:0.982718
# [7]	validation_0-auc:0.982833	validation_1-auc:0.982826
# [8]	validation_0-auc:0.982892	validation_1-auc:0.982865
# [9]	validation_0-auc:0.982928	validation_1-auc:0.982926
# [10]	validation_0-auc:0.982999	validation_1-auc:0.982993
# [11]	validation_0-auc:0.983016	validation_1-auc:0.983006
# [12]	validation_0-auc:0.984072	validation_1-auc:0.984104
# [13]	validation_0-auc:0.984036	validation_1-auc:0.98407
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X[:1000])
shap.summary_plot(shap_values, X, plot_type="bar",max_display = 9)
plt.xscale("log")

plt.show()

plt.plot(results['validation_0']['auc'], label='Train')
plt.plot(results['validation_1']['auc'], label='Train')
plt.show()

# %% [markdown]
# Test on real data

# %%
sns.set()

d = truedat[:int(1e6)]

y_pred = model.predict_proba(preprocess(d[ps]))
dpred = d[y_pred[:,0]<0.49]

# dpred = dpred[np.logical_and(dpred["v0_ks_mass"]>450,dpred["v0_ks_mass"]<550)]
c =npand(d["v0_ks_mass"]>450,d["v0_ks_mass"]<550)
d = d[c]
dpred = dpred[c]

fig,axs = plt.subplots(1,1,figsize=(10,6),sharey=True)
hist(d["v0_ks_mass"],ax = axs,label="Untouched K-short mass data")
hist(dpred["v0_ks_mass"],ax=axs,label="Data after a cut from a XGBoosted decision tree")
axs.legend(fontsize=12)
axs.set_title("Cut by XGBoost in MC",fontsize=14)
plt.savefig("cutbyML1.png")
plt.tight_layout()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,7))
nnfuncs.roc_curve_data(d["v0_ks_mass"],y_pred[:,0],ax_roc=axs[0],ax_fits=axs[1])
# Out:
# Completed fit with Chi2: 95.1, p-val: 0.363 and the total amount of signal 18763 +/- 376, background: 981238
# No valid minimum found!
# Completed fit with Chi2: 79.4, p-val: 0.803 and the total amount of signal 2127 +/- 10216, background: 897874
# Completed fit with Chi2: 70.0, p-val: 0.950 and the total amount of signal 639 +/- 200, background: 799361
# No valid minimum found!
# Completed fit with Chi2: 78.9, p-val: 0.813 and the total amount of signal 73 +/- 17598, background: 699927
# Completed fit with Chi2: 70.1, p-val: 0.949 and the total amount of signal 8 +/- 13, background: 599992
# Completed fit with Chi2: 74.2, p-val: 0.900 and the total amount of signal 0 +/- nan, background: 500000
# Completed fit with Chi2: 82.1, p-val: 0.738 and the total amount of signal 0 +/- 0, background: 400000
# Completed fit with Chi2: 87.2, p-val: 0.594 and the total amount of signal 78 +/- 79, background: 299923
# ...

# %% [markdown]
# # Lambda and Lambda-bar

# %%
lambdabarparameters = ['numberOfTRTHits1', 'npv', 'a0z', 'a0', 'pv0_y', 'v0_phi2', 'v0_chi2', 'numberOfPixelHits1', 'v0_x', 'v0_py', 'rapidity_ks', 'a0xy', 'eventCounter', 'v0_px', 'v0_z', 'pseudorapidity', 'v0_rxy', 'v0_y', 'pv0_z', 'pv0_x', 'cosTheta', 'ntrk_pv0', 'v0_pz', 'v0_rxyErr', 'v0_px2', 'rapidity_lb', 'v0_py2', 'v0_phi1', 'v0_ks_massErr', 'calpha', 'numberOfSCTHits1', 'v0_pt2', 'pL2', 'v0_pz2', 'rapidity_la', 'v0_qOverP2', 'v0_p2', 'epsilon1', 'v0_pt', 'v0_p', 'v0_theta2', 'v0_theta1', 'v0_la_massErr', 'v0_py1', 'v0_px1', 'epsilon2', 'pT', 'v0_ptErr']

amount = int(1e6)

X,y = scale_split(df_all[:amount],truedat_all[:amount],0.7,0.7,lambdaparameters),df_all[:amount][["trueLb"]]

# X = preprocess(X)
model = xgboost.XGBClassifier(learning_rate = 0.1,n_estimators = 100)
model.fit(X, y,eval_metric ="auc")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-065c861bbc39> in <module>
#       3 amount = int(1e6)
#       4
# ----> 5 X,y = scale_split(df_all[:amount],truedat_all[:amount],0.7,0.7,lambdaparameters),df_all[:amount][["trueLb"]]
#       6
#       7 # X = preprocess(X)
#
# NameError: name 'scale_split' is not defined

# %%
lambdaparameters = ['numberOfTRTHits1', 'npv', 'a0z', 'a0', 'pv0_y', 'v0_phi2', 'v0_chi2', 'numberOfPixelHits1', 'v0_x', 'v0_py', 'rapidity_ks', 'a0xy', 'eventCounter', 'v0_px', 'v0_z', 'pseudorapidity', 'v0_rxy', 'v0_y', 'pv0_z', 'pv0_x', 'cosTheta', 'ntrk_pv0', 'v0_pz', 'v0_rxyErr', 'v0_px2', 'rapidity_la', 'v0_py2', 'v0_phi1', 'v0_ks_massErr', 'calpha', 'numberOfSCTHits1', 'v0_pt2', 'pL2', 'v0_pz2', 'rapidity_lb', 'v0_qOverP2', 'v0_p2', 'epsilon1', 'v0_pt', 'v0_p', 'v0_theta2', 'v0_theta1', 'v0_lb_massErr', 'v0_py1', 'v0_px1', 'epsilon2', 'pT', 'v0_ptErr']
amount = int(1e6)

X,y = df_all[:amount][lambdaparameters],df_all[:amount][["trueLa"]]

# X = preprocess(X)
modela = xgboost.XGBClassifier(learning_rate = 0.1,n_estimators = 100)
modela.fit(X, y,eval_metric ="auc")
# Out:
# XGBClassifier()

# %%
testa = df_all[amount:amount+int(1e6)][lambdaparameters]
test = df_all[amount:amount+int(1e6)][lambdabarparameters]

goala = df_all[amount:amount+int(1e6)][["trueLa"]]
goal = df_all[amount:amount+int(1e6)][["trueLb"]]
prob = model.predict_proba(test)
proba = modela.predict_proba(testa)

auca = roc_auc_score(goala,proba[:,1])
roca = roc_curve(goala,proba[:,1])

auc = roc_auc_score(goal,prob[:,1])
roc = roc_curve(goal,prob[:,1])

fig, axs = plt.subplots(1,1,figsize=(10,5))
axs[0].plot(roca[0],roca[1],label="auc: {:.3}".format(auca))
axs[0].plot(roc[0],roc[1],label="auc: {:.3}".format(auc))

axs[0].legend()
# axs[0].legend()

axs[0].set_title("ROC-curve of XGBoost on lambda in MC")
# axs[].set_title("ROC-curve of XGBoost on lambda-bar in MC")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-070d887782f5> in <module>
# ----> 1 testa = df_all[amount:amount+int(1e6)][lambdaparameters]
#       2 test = df_all[amount:amount+int(1e6)][lambdabarparameters]
#       3
#       4 goala = df_all[amount:amount+int(1e6)][["trueLa"]]
#       5 goal = df_all[amount:amount+int(1e6)][["trueLb"]]
#
# NameError: name 'lambdaparameters' is not defined

# %%
argsor = np.argsort(model.feature_importances_)

np.flip(np.array(lambdaparameters)[argsor])
# Out:
# array(['v0_rxyErr', 'pT', 'v0_pt2', 'cosTheta', 'epsilon2',
#        'v0_la_massErr', 'epsilon1', 'v0_rxy', 'v0_chi2', 'calpha',
#        'numberOfSCTHits1', 'v0_ptErr', 'numberOfPixelHits1', 'v0_pt',
#        'a0xy', 'v0_qOverP2', 'v0_p', 'v0_ks_massErr', 'ntrk_pv0', 'a0z',
#        'v0_x', 'pL2', 'pv0_x', 'v0_z', 'v0_py', 'v0_p2', 'v0_y',
#        'v0_phi2', 'v0_theta1', 'rapidity_lb', 'npv', 'v0_pz2', 'a0',
#        'pv0_y', 'v0_px1', 'v0_phi1', 'v0_py2', 'rapidity_ks', 'v0_pz',
#        'v0_px2', 'eventCounter', 'v0_px', 'v0_theta2', 'pseudorapidity',
#        'v0_py1', 'rapidity_la', 'pv0_z', 'numberOfTRTHits1'], dtype='<U18')

# %%
ms = truedat_all[amount:amount+int(1e6)]["v0_la_mass"]
fig, axs = plt.subplots(1,2,figsize=(15,7))
nnfuncs.roc_curve_data_lambda(ms,proba[:,0],ax_roc=axs[0],ax_fits=axs[1],range=(1080,1160))
# Out:
# No background valid minimum found!
# No valid minimum found!
# Completed fit with Chi2: 972.8, p-val: 0.000 and the total amount of signal 690918 +/- 0, background: 309083
# No valid minimum found!
# Completed fit with Chi2: 878.2, p-val: 0.000 and the total amount of signal 622747 +/- 0, background: 277254
# No valid minimum found!
# Completed fit with Chi2: 806.0, p-val: 0.000 and the total amount of signal 557610 +/- 0, background: 242391
# No valid minimum found!
# Completed fit with Chi2: 722.0, p-val: 0.000 and the total amount of signal 486867 +/- 0, background: 213134
# No valid minimum found!
# Completed fit with Chi2: 612.0, p-val: 0.000 and the total amount of signal 405437 +/- 0, background: 194564
# No valid minimum found!
# Completed fit with Chi2: 532.2, p-val: 0.000 and the total amount of signal 334519 +/- 0, background: 165481

# %%
ms = truedat_all[amount:amount+int(1e6)]["v0_lb_mass"]
rng = np.logical_and(ms>1100,ms<1150)
tf = prob[:,0]>0.4

fig,axs = plt.subplots(1,2,figsize=(10,5))
axs[0].hist(ms[rng],100)
axs[1].hist(ms[tf][rng],100)
plt.show()

# %%
plt.hist(df_all["rapidity_ks"])
# Out:
# (array([ 80731., 249369., 279815., 227436., 191869., 197053., 239703.,
#         280745., 214449.,  38830.]),
#  array([-2.68347526, -2.13281925, -1.58216324, -1.03150723, -0.48085122,
#          0.06980479,  0.6204608 ,  1.17111681,  1.72177281,  2.27242882,
#          2.82308483]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_split(mcs, datas, split, quantile, paramlist, no_transform):
    mc1, data1=mcs[paramlist], datas[paramlist]
    testlen=int(len(mc)*(1-split))
    
    for param in paramlist:
        if param not in no_transform:
            print(param+' is being transformed' )
            q_mc, q_data = (mcs.quantile(1-quantile)[param], mcs.quantile(quantile)[param]), (datas.quantile(1-quantile)[param], datas.quantile(quantile)[param])
            mcq, dataq = mcs.loc[(mcs[param] > q_mc[0]) & (mcs[param] < q_mc[1])], datas.loc[(datas[param] > q_data[0]) & (datas[param] < q_data[1])]
            mcscaler, datascaler=MinMaxScaler().fit( (mcq[param]).to_numpy().reshape(-1, 1) ), MinMaxScaler().fit( (dataq[param]).to_numpy().reshape(-1, 1))  
            mcscaled, datascaled= mcscaler.transform( (mcs[param]).to_numpy().reshape(-1, 1) ), mcscaler.transform( (datas[param]).to_numpy().reshape(-1, 1) ) 
            mc1[param], data1[param]=mcscaled, datascaled
    true=mc.trueKs
    return mc1[:testlen], mc1[testlen:], data1[:testlen], data1[testlen:], true[:testlen], true[testlen:]
